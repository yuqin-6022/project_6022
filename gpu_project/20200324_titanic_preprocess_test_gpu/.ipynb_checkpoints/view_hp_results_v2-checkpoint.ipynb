# %%
import matplotlib.pyplot as plt
import os
import json

# %%
CUR_PATH = os.getcwd()

EXPERIMENT_NUM = 5
FILE_NAME = 'test_%d_json' % EXPERIMENT_NUM

def get_encoded():
    return 'encoded_titanic_dnn_keras_tuner.json'

def get_scaled():
    return 'scaled_titanic_dnn_keras_tuner.json'

def get_reducted(n):  # 2~ 9
    return 'reducted_%d_titanic_dnn_keras_tuner.json' % n

def get_selected(n):  # 4~ 9
    return 'selected_%d_titanic_dnn_keras_tuner.json' % n

def get_selectedandreducted(selected_n, reducted_n):  # 9(8 ~ 2), 8(7 ~ 2), 7(6 ~ 2), 6(5 ~ 2), 5(4 ~ 2)
    return 'selected_%d_reducted_%d_titanic_dnn_keras_tuner.json' % (selected_n, reducted_n)

# %%
def plot_history(histories):
    
    histories_index = tuple(range(len(histories)))
    colors = ['r', 'g', 'b']
    
    figsize = (19.2, 6.4)
    
    plt.figure(figsize=figsize)
    for i, history, color in zip(histories_index, histories, colors):
        fmt = '%s' % color
        loss = history['loss']
        plt.plot(loss, fmt, label=str(i))
    plt.legend()
    plt.title('loss')
    
    plt.figure(figsize=figsize)
    for i, history, color in zip(histories_index, histories, colors):
        val_fmt = '%s' % color
        val_loss = history['val_loss']
        plt.plot(val_loss, val_fmt, label=str(i))
    plt.legend()
    plt.title('val_loss')
    
    plt.figure(figsize=figsize)
    for i, history, color in zip(histories_index, histories, colors):
        fmt = '%s' % color
        accuracy = history['accuracy']
        plt.plot(accuracy, fmt, label=str(i))
    plt.legend()
    plt.title('accuracy')
    
    plt.figure(figsize=figsize)
    for i, history, color in zip(histories_index, histories, colors):
        val_fmt = '%s' % color
        val_accuracy = history['val_accuracy']
        plt.plot(val_accuracy, val_fmt, label=str(i))
    plt.legend()
    plt.title('val_accuracy')

# %%
def plot_multi_histories(get_func, min, max, k=0):
    
    colors = ['k', 'r', 'g', 'b', 'y', 'c', 'm', 'silver', 'peru', 'pink']
    figsize = (19.2, 6.4)
    
    operation = get_func.__name__.split('_')[1]
    
    plt.figure(figsize=figsize)
    for i in list(range(min, max + 1)):
        
        if not k:
            FILE_PATH = os.path.join(CUR_PATH, FILE_NAME, get_func(i))
        else:
            FILE_PATH = os.path.join(CUR_PATH, FILE_NAME, get_func(k, i))
        with open(FILE_PATH, 'r') as f:
            results = json.load(f)
        
        histories = tuple(json.loads(model_test_result['history'].replace('\'', '"')) for model_test_result in results['model_test_results'])
        val_fmt = '%s' % colors[i]
        val_accuracy = histories[0]['val_accuracy']
        plt.plot(val_accuracy, val_fmt, label='%s %d' % (operation, i))
    plt.legend()
    plt.title('val_accuracy')

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 数值编码结果
ENCODED_PATH = os.path.join(CUR_PATH, FILE_NAME, get_encoded())
with open(ENCODED_PATH, 'r') as f:
    results = json.load(f)

encoded_histories = tuple(json.loads(model_test_result['history'].replace('\'', '"')) for model_test_result in results['model_test_results'])
plot_history(encoded_histories)

# "num_layers": 2, "units_0": 32, "rate_0": 0.05, "units_1": 16, "rate_1": 0.1, "learning_rate": 0.01, "units_2": 208, "rate_2": 0.05, "units_3": 16, "rate_3": 0.45, "units_4": 16, "rate_4": 0.2, "units_5": 16, "rate_5": 0.25, "units_6": 80, "rate_6": 0.0, "units_7": 80, "rate_7": 0.0, "units_8": 16, "rate_8": 0.35000000000000003, "units_9": 80, "rate_9": 0.15000000000000002

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 无量纲化结果
SCALED_PATH = os.path.join(CUR_PATH, FILE_NAME, get_scaled())
with open(SCALED_PATH, 'r') as f:
    results = json.load(f)

SCALED_histories = tuple(json.loads(model_test_result['history'].replace('\'', '"')) for model_test_result in results['model_test_results'])
plot_history(SCALED_histories)

# "num_layers": 7, "units_0": 16, "rate_0": 0.5, "units_1": 16, "rate_1": 0.0, "learning_rate": 0.01, "units_2": 256, "rate_2": 0.0, "units_3": 256, "rate_3": 0.5, "units_4": 80, "rate_4": 0.1, "units_5": 208, "rate_5": 0.15000000000000002, "units_6": 48, "rate_6": 0.35000000000000003, "units_7": 144, "rate_7": 0.05, "units_8": 256, "rate_8": 0.5, "units_9": 176, "rate_9": 0.25

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 特征降维结果
plot_multi_histories(get_reducted, 2, 9)
plot_multi_histories(get_reducted, 4, 9)
plot_multi_histories(get_reducted, 6, 9)

# "num_layers": 2, "units_0": 224, "rate_0": 0.0, "units_1": 32, "rate_1": 0.0, "learning_rate": 0.01, "units_2": 16, "rate_2": 0.0, "units_3": 256, "rate_3": 0.4, "units_4": 256, "rate_4": 0.05, "units_5": 16, "rate_5": 0.0, "units_6": 224, "rate_6": 0.0, "units_7": 256, "rate_7": 0.25, "units_8": 16, "rate_8": 0.0, "units_9": 176, "rate_9": 0.0
# "num_layers": 2, "units_0": 32, "rate_0": 0.5, "units_1": 16, "rate_1": 0.0, "learning_rate": 0.01, "units_2": 160, "rate_2": 0.35000000000000003, "units_3": 16, "rate_3": 0.05, "units_4": 160, "rate_4": 0.15000000000000002, "units_5": 16, "rate_5": 0.0, "units_6": 16, "rate_6": 0.0, "units_7": 16, "rate_7": 0.0, "units_8": 208, "rate_8": 0.5, "units_9": 128, "rate_9": 0.0

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 特征选择结果
plot_multi_histories(get_selected, 4, 9)
plot_multi_histories(get_selected, 4, 6)

# "num_layers": 2, "units_0": 16, "rate_0": 0.0, "units_1": 256, "rate_1": 0.5, "learning_rate": 0.01, "units_2": 16, "rate_2": 0.0, "units_3": 256, "rate_3": 0.0, "units_4": 16, "rate_4": 0.0, "units_5": 256, "rate_5": 0.5, "units_6": 256, "rate_6": 0.0, "units_7": 16, "rate_7": 0.5, "units_8": 256, "rate_8": 0.0

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 特征选择、降维结果
plot_multi_histories(get_selectedandreducted, 2, 8, 9)
plot_multi_histories(get_selectedandreducted, 2, 7, 8)

# "num_layers": 2, "units_0": 80, "rate_0": 0.0, "units_1": 128, "rate_1": 0.0, "learning_rate": 0.01, "units_2": 48, "rate_2": 0.0, "units_3": 16, "rate_3": 0.1, "units_4": 224, "rate_4": 0.25, "units_5": 64, "rate_5": 0.0, "units_6": 80, "rate_6": 0.4, "units_7": 144, "rate_7": 0.1, "units_8": 16, "rate_8": 0.30000000000000004
# "num_layers": 2, "units_0": 112, "rate_0": 0.0, "units_1": 16, "rate_1": 0.25, "learning_rate": 0.01, "units_2": 16, "rate_2": 0.0, "units_3": 16, "rate_3": 0.0, "units_4": 16, "rate_4": 0.0, "units_5": 16, "rate_5": 0.0, "units_6": 16, "rate_6": 0.0, "units_7": 16, "rate_7": 0.25, "units_8": 256, "rate_8": 0.30000000000000004, "units_9": 16, "rate_9": 0.0

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------

# %%
# "num_layers": 2, "units_0": 32, "rate_0": 0.05, "units_1": 16, "rate_1": 0.1, "learning_rate": 0.01

# "num_layers": 7, "units_0": 16, "rate_0": 0.5, "units_1": 16, "rate_1": 0.0, "learning_rate": 0.01, "units_2": 256, "rate_2": 0.0, "units_3": 256, "rate_3": 0.5, "units_4": 80, "rate_4": 0.1, "units_5": 208, "rate_5": 0.15000000000000002, "units_6": 48, "rate_6": 0.35000000000000003

# "num_layers": 2, "units_0": 224, "rate_0": 0.0, "units_1": 32, "rate_1": 0.0, "learning_rate": 0.01
# "num_layers": 2, "units_0": 32, "rate_0": 0.5, "units_1": 16, "rate_1": 0.0, "learning_rate": 0.01

# "num_layers": 2, "units_0": 16, "rate_0": 0.0, "units_1": 256, "rate_1": 0.5, "learning_rate": 0.01

# "num_layers": 2, "units_0": 80, "rate_0": 0.0, "units_1": 128, "rate_1": 0.0, "learning_rate": 0.01
# "num_layers": 2, "units_0": 112, "rate_0": 0.0, "units_1": 16, "rate_1": 0.25, "learning_rate": 0.01

# %%
# 最佳结果
BEST_PATH = os.path.join(CUR_PATH, FILE_NAME, get_reducted(9))
with open(BEST_PATH, 'r') as f:
    results = json.load(f)

best_history = tuple(json.loads(model_test_result['history'].replace('\'', '"')) for model_test_result in results['model_test_results'])[0]

val_accuracy = best_history['val_accuracy']
best_val_accuracy = max(val_accuracy)
best_epoch = val_accuracy.index(best_val_accuracy)
print(best_epoch, best_val_accuracy)
# Out:
# 454 0.8888889

# %%
# 最佳结果
BEST_PATH = os.path.join(CUR_PATH, FILE_NAME, get_reducted(8))
with open(BEST_PATH, 'r') as f:
    results = json.load(f)

best_history = tuple(json.loads(model_test_result['history'].replace('\'', '"')) for model_test_result in results['model_test_results'])[0]

val_accuracy = best_history['val_accuracy']
best_val_accuracy = max(val_accuracy)
best_epoch = val_accuracy.index(best_val_accuracy)
print(best_epoch, best_val_accuracy)
# Out:
# 437 0.9
